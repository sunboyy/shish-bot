# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import re
import string

def clean_stopword(text):
    # Apply this code to every textual string
    word_list = text.split() 
    filtered_words = [word for word in word_list if word not in stopwords.words('english')]
    text = ' '.join(filtered_words)
    return text


# # Remove Punctuatio
def remove_punc(text):
    punctuation = set(string.punctuation)
    except_punc = ['?', '!', '\"', ',', '.']
    for ex in except_punc:
        punctuation.remove(ex)
    out = []
    for e in list(text):

        if e in except_punc:
            if e != '.' :
                out.append(" "+e)
            else :
                out.append(".")
        elif e not in punctuation or e is '\'':
            out.append(e)
        else :
            out.append(" ")
    return "".join(out)

# # Split contraction (include 'em 'til)
def split_contraction(phrase):
    # convert two types of single qoute
    phrase = re.sub(r"’", "'", phrase)
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    
    phrase = re.sub(r"\'em ", "them ", phrase)
    phrase = re.sub(r"\'til", "until", phrase)
    
    phrase = re.sub(r"y\'", " you ", phrase)
    
    phrase = re.sub(r"in'", "ing", phrase)
    
    # general

    phrase = re.sub(r"n \'t", " n\'t", phrase)
    
    phrase = re.sub(r"n\'t", " n\'t", phrase)
    phrase = re.sub(r"\'re", " 're", phrase)
    phrase = re.sub(r"\'s", " 's", phrase)
    phrase = re.sub(r"\'d", " 'd", phrase)
    phrase = re.sub(r"\'ll", " 'll", phrase)
    phrase = re.sub(r"\'ve", " 've", phrase)
    phrase = re.sub(r"\'m", " 'm", phrase)
    
    return phrase


# # Group up contigous white space
def group_space(text):
    return " ".join(text.split())

# # ' Expand the qoutation mark '
def expand_qoute(text):
    # remove punctuation first
    out = []
    for i in range(len(text)):
        if text[i] == "\'": 
            if(i!=0 and text[i-1] == ' '): #start qoute
                out.append("' ")
            elif(text[i+1] == ' ' and text[i-1]!=" "): #end qoute
                out.append(" '")
        else: out.append(text[i])
    return "".join(out)


# # Pad < end >
def find_dot(text):
    index = -1 
    reverse_text = text[::-1]
    for i in range(len(reverse_text)):
        if(reverse_text[i] =='.'):
            index = len(text)-i
        else:
            break
    return index

def pad_end_of_sentence(sentences):
    out = []
    for sentence in sentences:
        if len(sentence) > 0 and sentence[-1] == '.':
            out.append(sentence[:find_dot(sentence)-1])
        else: 
            out.append(sentence)
    return " <end> ".join(out) + ' <end>'
 
# ## Capital check
def capital_clean(sentence):
    return sentence.lower()

# ## Check symbols
def have_alphabet(sentence):
    for char in sentence:
        if char.isalpha():
            return True
    return False

# # Clean Function
def clean_data_main(line):
    sentences = sent_tokenize(line)
    out_sentences = []
    for sentence in sentences :
        if not have_alphabet(sentence):
            continue
        x = capital_clean(sentence)
        x = split_contraction(x)
        x = remove_punc(x)
        x = group_space(x)
        out_sentences.append(x)     
    sentence = pad_end_of_sentence(out_sentences)
    return sentence


# # Reverse Function
def recontraction(phrase):
    phrase = re.sub(r"’", "'", phrase)
    # specific
    phrase = re.sub(r"will not", "won\'t", phrase)
    phrase = re.sub(r"can not", "can\'t", phrase)
    
    phrase = re.sub(r"them", "\'em", phrase)
    phrase = re.sub(r"until", "\'til", phrase)
    
    # general

    phrase = re.sub(r" n\'t", "n't", phrase)
    phrase = re.sub(r" \'re", "'re", phrase)
    phrase = re.sub(r" \'s", "'s", phrase)
    phrase = re.sub(r" \'d", "'d", phrase)
    phrase = re.sub(r" \'ll", "'ll", phrase)
    phrase = re.sub(r" \'ve", "'ve", phrase)
    phrase = re.sub(r" \'m", "'m", phrase)
    
    return phrase

import pickle
with open('lowerToCappital.pkl', 'rb') as handle:
    lowerToCapital = pickle.load(handle)

lowerToCapital['i'] = 'I'

def apply_capital(line):
    out = []
    startWord = True
    for word in line.split():
        if(startWord) :
            out.append(word.capitalize())
            startWord = False
            continue
        if word in lowerToCapital:
            out.append(lowerToCapital[word])
        else :
            out.append(word)
    return " ".join(out)

def remove_space_between_punctuation(line) :
    out = ''
    punctuation = set(string.punctuation)
    for i in range(len(line)) :
        try:
            if line[i] == ' ' and line[i-1] in punctuation and line[i+1] in punctuation:
                pass
            else :
                out+=line[i]
        except :
            pass
    return out            

def reverse_clean(data) :
    first_question = ['who', 'what', 'where', 'when', 'why', 'how', 'do', 'does', 'is', 'are', 'am', 'did', 'have', 'has', 'had', 'can', 'could', 'may', 'might', 'would', 'want']
    out = []
    sentences = data.split('<end>')
    for sentence in sentences:
        if len(sentence)<=0:
            continue
        x = recontraction(sentence)
        x = remove_space_between_punctuation(x)
        x = apply_capital(x)
        x = x.strip()
        if x.split()[0].split("'")[0].lower() not in first_question:
            x += '.' 
        else:
            x += '?'
        out.append(x)
    return " ".join(out)

# print(reverse_clean("i do n't want to know how to say that though <end> i want to know useful things <end> like where the good stores are <end> how much does champagne cost <end> stuff like chat <end> i have never in my life had to point out my head to someone <end>"))
# print(clean_data_main("What are you doing? My name is Jump. I like you."))

with open('data_QA.pickle', 'rb') as handle:
    data = pickle.load(handle)

res = dict()

import random, json, re
random.seed(129)
random.shuffle(data)

for i in range(500):
    res[2*i + 1] = (reverse_clean(data[i][0]), reverse_clean(data[i][1]))
    res[2*i + 2] = (reverse_clean(data[i][0]), reverse_clean(data[i][2]))

# %%
res
# Out:
# {1: ('Would you excuse me for a moment?', 'Sure.'),
#  2: ('Would you excuse me for a moment?', "I'd like to know."),
#  3: ("It's so cruel.", 'No. He had the choice.'),
#  4: ("It's so cruel.", "And you're a good man."),
#  5: ('Thank you.', 'Want another one?'),
#  6: ('Thank you.', "I'll be in the back."),
#  7: ("Honey you'll wake the whole neighborhood.", 'Mom.'),
#  8: ("Honey you'll wake the whole neighborhood.", 'What is it?'),
#  9: ('You said he was dead.', 'He is. But he was here.'),
#  10: ('You said he was dead.', "He's a girl."),
#  11: ('You gonna dig up that lad you s husband.', "I'll call the coroner."),
#  12: ('You gonna dig up that lad you s husband.',
#   "It's a nice time. I'm sorry."),
#  13: ('I better keep looking.', 'Where how?'),
#  14: ('I better keep looking.', "You're right."),
#  15: ('Jesus.', 'The business has changed.'),
#  16: ('Jesus.', "You're not going to do it."),
#  17: ('Hello.', 'Are you still coming?'),
#  18: ('Hello.', 'Hello.'),
#  19: ("Try 'flintstone '.", 'What?'),
#  20: ("Try 'flintstone '.", "And what's the difference."),
#  21: ('Hey lost again.',
#   'But perhaps there is some some less radical solution.'),
#  22: ('Hey lost again.', "Don't touch."),
#  23: ('Do you smell shit?', 'Yeah.'),
#  24: ('Do you smell shit?', "No i'm not just sure."),
#  25: ("Of joanne's.", "Yeah. I'm her father."),
#  26: ("Of joanne's.", "He's a little."),
#  27: ('How you guys doing?', "It's on."),
#  28: ('How you guys doing?', 'Fine.'),
#  29: ('Where you guys at?', 'Driving in circles waiting for.'),
#  30: ('Where you guys at?', "I'm not leaving."),
#  31: ('Have you succeeded in your task?', 'Any day now.'),
#  32: ('Have you succeeded in your task?', 'Not yet.'),
#  33: ("How's the trout?", 'It tastes like fish.'),
#  34: ("How's the trout?", "I'm not sure."),
#  35: ('No.', 'Or your baby brother. What was his name?'),
#  36: ('No.', "You're not."),
#  37: ("Yeah it's me.", 'Judge hold on is your phone safe.'),
#  38: ("Yeah it's me.", 'What are you doing here?'),
#  39: ("I don't get it.", "It doesn't make any sense."),
#  40: ("I don't get it.", "I don't know."),
#  41: ('The Archdiocese called they want to settle her estate.',
#   "And you're going to do that."),
#  42: ('The Archdiocese called they want to settle her estate.',
#   "And you're not making sense."),
#  43: ("I'm not sad.", "You're not."),
#  44: ("I'm not sad.", "You're shouting at me."),
#  45: ("It's not right.", 'I hate it.'),
#  46: ("It's not right.", "You know what i'm saying."),
#  47: ('Tonight.', 'Any night.'),
#  48: ('Tonight.', "I'll be back in the morning."),
#  49: ('Now what.', "There's the fence."),
#  50: ('Now what.', 'The beach.'),
#  51: ('Right. Wait. A toast.', "You're just afraid to eat it."),
#  52: ('Right. Wait. A toast.', 'A little a man.'),
#  53: ("I'm going to see you again right.", "If it's okay with you."),
#  54: ("I'm going to see you again right.", "I'm not going to hurt you."),
#  55: ('How was your flight?', 'Fine.'),
#  56: ('How was your flight?', 'Fine.'),
#  57: ('Everything okay.', 'Yes thank you very much.'),
#  58: ('Everything okay.', 'Yeah.'),
#  59: ('Affirmative.', 'The two surfer boys.'),
#  60: ('Affirmative.', "So you're not a guy."),
#  61: ('Good night dad.', 'Good night kiddo.'),
#  62: ('Good night dad.', 'Good night.'),
#  63: ('Holding hands.', 'No not holding hands.'),
#  64: ('Holding hands.', "What's wrong?"),
#  65: ("I'll take sixth. It's faster.", 'What?'),
#  66: ("I'll take sixth. It's faster.", "I'll be back in a few hours."),
#  67: ("Look he's in pretty good shape.", 'Poor Ike.'),
#  68: ("Look he's in pretty good shape.", "Hey don't be a nice man."),
#  69: ('You know I play tenor sax.', "But you're a girl thank goodness."),
#  70: ('You know I play tenor sax.', 'Yes.'),
#  71: ("I had you pegged didn't I.", 'You had the whole human race pegged.'),
#  72: ("I had you pegged didn't I.", 'Not really.'),
#  73: ('Are you?', 'No.'),
#  74: ('Are you?', 'What do you think I do?'),
#  75: ('Mmmm.', "It's a surprise you see."),
#  76: ('Mmmm.', 'Right.'),
#  77: ('You know what the Scottish call it.', 'No.'),
#  78: ('You know what the Scottish call it.', "I'm sorry. I'm not."),
#  79: ("It's a wonderful life.", 'Or the Bijou. Either one.'),
#  80: ("It's a wonderful life.", 'I know.'),
#  81: ('Man that one made me puke.', 'You forgot something.'),
#  82: ('Man that one made me puke.', "Hey it's a little of a mystery."),
#  83: ('No.', 'Following the game at all.'),
#  84: ('No.', 'What do you want?'),
#  85: ('I see.', 'Your foot. Give me your foot.'),
#  86: ('I see.', "You're a policeman."),
#  87: ('A symbol master.', 'What kind of symbol?'),
#  88: ('A symbol master.', 'In the world.'),
#  89: ("Hey are you hungry. I'm hungry.", "Lois you're amazing."),
#  90: ("Hey are you hungry. I'm hungry.", 'Sure.'),
#  91: ('Did he try to?', 'No. Quid pro quo doctor.'),
#  92: ('Did he try to?', 'No.'),
#  93: ("All right i'll try. See you later.",
#   "Tomorrow at the gym. Don't forget."),
#  94: ("All right i'll try. See you later.", 'Okay.'),
#  95: ('I you know they should be insured.', 'What do you care?'),
#  96: ('I you know they should be insured.', "Don't be so literal."),
#  97: ('The readings suck.', "Maybe it's the tags that suck."),
#  98: ('The readings suck.', 'Invasion.'),
#  99: ('No. I meant.', 'What?'),
#  100: ('No. I meant.', "I've got a feeling."),
#  101: ("What'd ya see?", 'Cops.'),
#  102: ("What'd ya see?", 'A ride.'),
#  103: ("I'll call. I really will.", 'I know.'),
#  104: ("I'll call. I really will.", "Don't."),
#  105: ('But if you were.', "I. I can't answer that precisely."),
#  106: ('But if you were.', "I don't know."),
#  107: ('Enough of that. Name your terms.', 'Elizabeth goes free.'),
#  108: ('Enough of that. Name your terms.', "I'm not going to."),
#  109: ('How much?', 'Twenty eight hundred.'),
#  110: ('How much?', "I don't know."),
#  111: ('I have two right feet.', 'Good. I have two left.'),
#  112: ('I have two right feet.', 'Not that.'),
#  113: ("Let's go.", 'Anything you say baby.'),
#  114: ("Let's go.", "I'm not going to go with you."),
#  115: ('When?', 'Tonight. At the boardwalk.'),
#  116: ('When?', 'Tomorrow.'),
#  117: ('You were right. He found me.', "And you're working with him."),
#  118: ('You were right. He found me.', "Didn't you know that."),
#  119: ('Alvy I.', "What what what what's the matter?"),
#  120: ('Alvy I.', "I'm trying to help you."),
#  121: ('What are you doing?', 'Oh uh I resigned.'),
#  122: ('What are you doing?', 'What are you talking about?'),
#  123: ('What it will be?', 'How did you get in here?'),
#  124: ('What it will be?', "We don't know what I mean."),
#  125: ('Is this national security stuff boring you?',
#   'Put a tap on her phone.'),
#  126: ('Is this national security stuff boring you?', "Yeah. I don't have a."),
#  127: ("And tell me that she's happy.", 'Oh Dmitri I wish that I could.'),
#  128: ("And tell me that she's happy.", "He's a Macleod."),
#  129: ('You want to get into this now.', 'No no Caesar. Not now.'),
#  130: ('You want to get into this now.', 'Yes.'),
#  131: ("No bigger. What's the biggest energy?", 'The sun.'),
#  132: ("No bigger. What's the biggest energy?", 'A.'),
#  133: ("We can't stop.", 'The you ve tricked us.'),
#  134: ("We can't stop.", "I'm sorry."),
#  135: ('It was in your book.', 'Well hell maybe we do have a chance.'),
#  136: ('It was in your book.', 'I know.'),
#  137: ('Actually yes.', 'Hmmm.'),
#  138: ('Actually yes.', "You don't believe that."),
#  139: ('What did he say?', 'He says he feels safe here.'),
#  140: ('What did he say?', "I don't know."),
#  141: ("C'mon i'll buy you a drink.", "You haven't got any money."),
#  142: ("C'mon i'll buy you a drink.", 'Okay.'),
#  143: ('Hi.', 'Hi.'),
#  144: ('Hi.', "I'm Randy."),
#  145: ("You're right.", "You see they don't really know me."),
#  146: ("You're right.", "You're sure."),
#  147: ('How was school today?', 'Fine.'),
#  148: ('How was school today?', 'Fine.'),
#  149: ("It's a spice rack.", 'We desperately need a spice rack. Desperately.'),
#  150: ("It's a spice rack.", 'Oh.'),
#  151: ('What do you think of that Jabez?', 'Looks right elegant mary.'),
#  152: ('What do you think of that Jabez?', "I'm not going to say it."),
#  153: ("You're a killer Ozzy.", 'Thanks coach.'),
#  154: ("You're a killer Ozzy.", 'It was a little of a fucking thing.'),
#  155: ('I want him to at least see the sky.', 'And we will.'),
#  156: ('I want him to at least see the sky.', "You're not a."),
#  157: ('Uh huh.', "And you're solid on that."),
#  158: ('Uh huh.', "What's that?"),
#  159: ('What are you?', 'I am the clitoris.'),
#  160: ('What are you?', 'Open up.'),
#  161: ("I'm off.", "Wish you weren't."),
#  162: ("I'm off.", 'What?'),
#  163: ('His parents.', "Good god. Let's go rescue him."),
#  164: ('His parents.', 'Yes my beloved name.'),
#  165: ('You want your surprise.', 'Yeah. I want it.'),
#  166: ('You want your surprise.', "I don't want to talk about it."),
#  167: ('Yeah roz.', 'Any sign of our friend.'),
#  168: ('Yeah roz.', 'The driver party.'),
#  169: ('All right.', 'When do the girls get to the party?'),
#  170: ('All right.', 'Yeah.'),
#  171: ('Yes.', 'Do you walk home?'),
#  172: ('Yes.', "You're not a thief."),
#  173: ('Mine.', 'Have you always had it?'),
#  174: ('Mine.', 'What?'),
#  175: ('Gosh if only we could find Kat a boyfriend.',
#   'Let me see what I can do.'),
#  176: ('Gosh if only we could find Kat a boyfriend.', 'Yes sir.'),
#  177: ("Can you get 'em back?", "I'm trying."),
#  178: ("Can you get 'em back?", "You're going to get out of here."),
#  179: ('Maybe. Maybe not.', 'Abort the cruise.'),
#  180: ('Maybe. Maybe not.', 'What do you mean?'),
#  181: ("I can't take her with me.", 'Nobody asked you to.'),
#  182: ("I can't take her with me.", "Don't be stupid. Please."),
#  183: ('Okay.', 'Did you hide the letters?'),
#  184: ('Okay.', "I'm sorry."),
#  185: ('Why did you come tonight? To see me.', "To hear 'em read Torah."),
#  186: ('Why did you come tonight? To see me.',
#   "I didn't know you're not here."),
#  187: ('Out of the mouths of babes louis.', 'This babe has said enough.'),
#  188: ('Out of the mouths of babes louis.', 'What?'),
#  189: ("You're not going up there.", 'Yes I am.'),
#  190: ("You're not going up there.", 'No.'),
#  191: ('What?', 'I saw a man die.'),
#  192: ('What?', "I'm sorry."),
#  193: ("Where did you get 'em developed?", 'Assumed name Houston.'),
#  194: ("Where did you get 'em developed?", "It's mine."),
#  195: ("You didn't have to.", 'I just need you to be safe.'),
#  196: ("You didn't have to.", "You don't like it."),
#  197: ('Brett is the name.', 'Mr Denby and Mr McKinney.'),
#  198: ('Brett is the name.', 'Oh.'),
#  199: ("Don't be stupid they.", 'Bastard. If you were a true American.'),
#  200: ("Don't be stupid they.", "I'm not scared."),
#  201: ('You get it yet.', 'Naw nothing.'),
#  202: ('You get it yet.', "I don't know. I."),
#  203: ('You hungry or thirsty or both.', "I don't know."),
#  204: ('You hungry or thirsty or both.', 'Not at all.'),
#  205: ('He owned the water department.', 'Yes.'),
#  206: ('He owned the water department.', "He's a big one."),
#  207: ("We're going to be moving son.", 'Do we have to?'),
#  208: ("We're going to be moving son.", "I'll get the money."),
#  209: ('Care for a splash of wine Abbe.', "It's not even noon."),
#  210: ('Care for a splash of wine Abbe.', "I'm not hungry."),
#  211: ('Not entirely. No.', 'You sure about that.'),
#  212: ('Not entirely. No.', "Then what do you think you're saying."),
#  213: ('Are those your words?', 'Yes.'),
#  214: ('Are those your words?', 'What?'),
#  215: ('National television.', 'Abc.'),
#  216: ('National television.', 'Yeah.'),
#  217: ("I want 'em all.", 'I want to talk to Leon.'),
#  218: ("I want 'em all.", "I'm sorry about that."),
#  219: ('Who knows you have these?', 'Only you and the photo lab.'),
#  220: ('Who knows you have these?', 'What?'),
#  221: ("Didn't you have any panties on.", "He reached up and tore 'em."),
#  222: ("Didn't you have any panties on.", 'No.'),
#  223: ('Such pretty knees for a big boy.', 'Do I actually see this?'),
#  224: ('Such pretty knees for a big boy.', "I'll be."),
#  225: ('Sank you. Velcome. Sank you.', "What's cooking Bert?"),
#  226: ('Sank you. Velcome. Sank you.', 'Aye. I was in the state.'),
#  227: ('Why?', "Because it's the rules."),
#  228: ('Why?', "Because i'm going to be honest."),
#  229: ('Thanks for nothing. I hate snakes.', 'I know the feeling.'),
#  230: ('Thanks for nothing. I hate snakes.', "Don't be afraid you're hungry."),
#  231: ("She doesn't seem to understand.", 'Try another language.'),
#  232: ("She doesn't seem to understand.", 'What do you mean?'),
#  233: ('I figured.', 'Was it worth it.'),
#  234: ('I figured.', 'You know.'),
#  235: ("You wouldn't believe me.", 'I would.'),
#  236: ("You wouldn't believe me.", "You're not a thing."),
#  237: ("Kramer there's something I ought to tell you.", 'Yeah.'),
#  238: ("Kramer there's something I ought to tell you.", 'You know.'),
#  239: ("It's what he said i'm his associate.",
#   'You must bring something heavy to the deal.'),
#  240: ("It's what he said i'm his associate.", 'What?'),
#  241: ('You would not believe what.', 'Shhh.'),
#  242: ('You would not believe what.', 'The you ll be here.'),
#  243: ('They killed the goose.', 'They did.'),
#  244: ('They killed the goose.', "And you're a doctor."),
#  245: ('That makes it worse.', "But I don't understand."),
#  246: ('That makes it worse.', "You're a lot of shit and."),
#  247: ('That girl was Amanda Krueger. Her child.', 'Freddy.'),
#  248: ('That girl was Amanda Krueger. Her child.', "He said he's a good."),
#  249: ('Well thank you again.', 'Oh yeah yeah.'),
#  250: ('Well thank you again.', "You're a girl."),
#  251: ('I second the motion.', 'Atta boy Cheswick.'),
#  252: ('I second the motion.', 'Overruled.'),
#  253: ('I know.', 'But you could go to jail for it.'),
#  254: ('I know.', "It's not your fault."),
#  255: ('No her dog.', 'Oh she bit her dog eh.'),
#  256: ('No her dog.', "Oh yes you're so good."),
#  257: ("Don't you have school.", 'Nope.'),
#  258: ("Don't you have school.", "I don't know."),
#  259: ('A friend from school.', 'A special friend.'),
#  260: ('A friend from school.', 'Yeah.'),
#  261: ('When?', 'When we know?'),
#  262: ('When?', 'Tomorrow.'),
#  263: ('Well terrorists of course.',
#   'How many terrorists have you met? Actual terrorists.'),
#  264: ('Well terrorists of course.', 'How are you?'),
#  265: ("Oh Lloyd you gotta taste my mom's pie.",
#   'So boys how was your first day.'),
#  266: ("Oh Lloyd you gotta taste my mom's pie.", 'Oh well.'),
#  267: ('Turn on the t v.', "I did. Isn't it neat o."),
#  268: ('Turn on the t v.', "I'm sorry."),
#  269: ('Why?', 'Lynn.'),
#  270: ('Why?', "Because I don't want to."),
#  271: ('Are you okay?', "Yes i'm sorry."),
#  272: ('Are you okay?', "I'm fine."),
#  273: ('Yes.', "We'll stop then."),
#  274: ('Yes.', "You've got to go."),
#  275: ("Mr Beckett i'm sorry.", 'About my blood work.'),
#  276: ("Mr Beckett i'm sorry.", "I'm not going to get out of here."),
#  277: ('Dude.', 'That makes me feel all warm inside.'),
#  278: ('Dude.', 'Yes.'),
#  279: ('Lester he called you here.', 'Right.'),
#  280: ('Lester he called you here.', "I said you're not a girlfriend."),
#  281: ('Huh. Oh yeah.', 'You want your gear. Here you go.'),
#  282: ('Huh. Oh yeah.', 'I seen it.'),
#  283: ("I'll open mine now.", "I'll open mine too."),
#  284: ("I'll open mine now.", "I'll be back."),
#  285: ('John where are we g.', 'Hush.'),
#  286: ('John where are we g.', "We'll get it."),
#  287: ('Oh that was many years ago.', 'Tell me more.'),
#  288: ('Oh that was many years ago.', "Yeah. I'm sure you know."),
#  289: ('Doing what.', 'Talking.'),
#  290: ('Doing what.', 'Vivian.'),
#  291: ("What's in the other direction?",
#   'This road it leads straight to Kuwait.'),
#  292: ("What's in the other direction?", 'What?'),
#  293: ('Great.', "I'll tape it for you."),
#  294: ('Great.', "I'm fine. I'm not hungry."),
#  295: ('I I love I pat Benatar.', 'Yeah. Well. I loved her too.'),
#  296: ('I I love I pat Benatar.', "I'm sorry."),
#  297: ('Oh nick nick.', 'Hello Mimi.'),
#  298: ('Oh nick nick.', 'What is it?'),
#  299: ('Of what.', "That dillinger's on to him."),
#  300: ('Of what.', 'The Albanian campaign.'),
#  301: ('Uncle Alfred.', "In spirit only i'm afraid."),
#  302: ('Uncle Alfred.', 'The grapes of wrath.'),
#  303: ("Oh well you you're not interested in this.", 'No you can tell me.'),
#  304: ("Oh well you you're not interested in this.",
#   "Oh i'm sorry. I'm sorry."),
#  305: ('Yes.', "That's life. What can I tell you?"),
#  306: ('Yes.', "I'm going to settle with her."),
#  307: ('So what are you up to now.', "I'm robbing this place."),
#  308: ('So what are you up to now.', 'You have to be a bit.'),
#  309: ('Captain what do you want.', 'Call me Dudley.'),
#  310: ('Captain what do you want.', 'Just a little.'),
#  311: ('I refuse to be your slave. I refuse.', "To fight. We'll see."),
#  312: ('I refuse to be your slave. I refuse.', "You're a good man."),
#  313: ('Trust me. It will be bad.', 'What do you mean bad?'),
#  314: ('Trust me. It will be bad.', "Don't worry. I'm going to get out."),
#  315: ('You got me. Afraid of bad news.', 'Nope.'),
#  316: ('You got me. Afraid of bad news.', "I don't know what i'm saying."),
#  317: ('Do you?', "Let's change the subject."),
#  318: ('Do you?', 'Yes.'),
#  319: ("I don't want you to leave tomorrow.", "I don't understand."),
#  320: ("I don't want you to leave tomorrow.", 'Why?'),
#  321: ("You understand what you'll be doing.",
#   'Yeah you just want me to wave right.'),
#  322: ("You understand what you'll be doing.", "What's going to happen?"),
#  323: ('Hi Plato.', 'Hi.'),
#  324: ('Hi Plato.', 'Hi.'),
#  325: ('What?', 'Look.'),
#  326: ('What?', 'The you re screaming in court.'),
#  327: ("And you're solid on that.", 'Rock solid.'),
#  328: ("And you're solid on that.", 'I think so.'),
#  329: ('Any group pictures in the annual.', 'Nothing. No mention of it.'),
#  330: ('Any group pictures in the annual.', "I don't think he's happy."),
#  331: ('That movie makes me feel guilty.', "Yeah 'cause it's supposed to."),
#  332: ('That movie makes me feel guilty.',
#   "You're going to be a very long ship."),
#  333: ('What? Right here.', 'Step into my office.'),
#  334: ('What? Right here.', 'What about it?'),
#  335: ('Videotapes.', 'I can see that. What are they?'),
#  336: ('Videotapes.', 'Charlie.'),
#  337: ('Trans ocean travel.', 'Is that Ryuji?'),
#  338: ('Trans ocean travel.', 'He was a good man.'),
#  339: ('But.', 'Such is the price of patriotism.'),
#  340: ('But.', "You're going to get out of here now."),
#  341: ('What?', 'What is the question you asked me?'),
#  342: ('What?', "I don't know what i'm saying."),
#  343: ('I just had a phone call.', 'Tell me is it bad news.'),
#  344: ('I just had a phone call.', "You're not here."),
#  345: ('That was unfortunate.', 'That was a calamity.'),
#  346: ('That was unfortunate.', 'Uh uh.'),
#  347: ("You'll never get away with it miss Andrews.",
#   'What are you talking about?'),
#  348: ("You'll never get away with it miss Andrews.", 'I did.'),
#  349: ('Bullshit.', 'Well maybe two seventeen.'),
#  350: ('Bullshit.', "You know what i'm saying."),
#  351: ('She knows you real self.', 'She knows how she feel.'),
#  352: ('She knows you real self.', "I didn't say that."),
#  353: ('What is going to happen? Where is Harry?',
#   "He's safe in the Russian zone."),
#  354: ('What is going to happen? Where is Harry?',
#   "I'll get you a few minutes."),
#  355: ('What makes Sammy run?', 'I said my name is Eddie Lovell.'),
#  356: ('What makes Sammy run?', "I'm not a man."),
#  357: ("It'll come back to him.", "Are you sure? That's what I thought."),
#  358: ("It'll come back to him.", 'What?'),
#  359: ("''.", 'Oh.'),
#  360: ("''.", "''."),
#  361: ('Hey Murph.', 'Roc. You okay.'),
#  362: ('Hey Murph.', "Roc. I'm sorry."),
#  363: ('Do you think you won?', 'It was nip and tuck.'),
#  364: ('Do you think you won?', 'What?'),
#  365: ('Hello.', 'What happened to that guy?'),
#  366: ('Hello.', 'Hi.'),
#  367: ('Viktor you should have said something.', "She doesn't want pity."),
#  368: ('Viktor you should have said something.', 'Hello.'),
#  369: ("He wasn't there.", 'What?'),
#  370: ("He wasn't there.", "I'll get it."),
#  371: ('What are you talking about?', 'You know.'),
#  372: ('What are you talking about?', "I don't know."),
#  373: ("We don't need him.", "We don't."),
#  374: ("We don't need him.", 'What do you want?'),
#  375: ('I heard that too.', 'Did you hear his son is still around?'),
#  376: ('I heard that too.', "What's that?"),
#  377: ('Excuse us dear.', "It's okay Dan."),
#  378: ('Excuse us dear.', 'Hey.'),
#  379: ('God.', 'What?'),
#  380: ('God.', "I don't know what's going on."),
#  381: ('Just trying to get my apartment in order.', 'Can I lend you a hand?'),
#  382: ('Just trying to get my apartment in order.',
#   "I'm not scared about this."),
#  383: ('Please sir come with me.', 'No Jeff please.'),
#  384: ('Please sir come with me.', "You don't have to do it."),
#  385: ('Sometimes.', 'Sometimes which.'),
#  386: ('Sometimes.', "What do you think i'm?"),
#  387: ('The door needs a lock.', "Sure. I'll fix it right away."),
#  388: ('The door needs a lock.', 'No.'),
#  389: ('You really want to go.', 'Of course.'),
#  390: ('You really want to go.', 'Yes.'),
#  391: ('Did you ever eat fish heads and rice?', 'Of course not.'),
#  392: ('Did you ever eat fish heads and rice?', "I didn't think so."),
#  393: ('Good afternoon Mr Campbell.', 'Mr Mitchell.'),
#  394: ('Good afternoon Mr Campbell.', 'Good night Shirley.'),
#  395: ("Fuck her. Come on let's go.", "Jeff. Let's go."),
#  396: ("Fuck her. Come on let's go.", "Don't start with me."),
#  397: ("M'hm.", 'And blind people crippled.'),
#  398: ("M'hm.", 'What?'),
#  399: ("That's enough.", "I'm sorry."),
#  400: ("That's enough.", 'What?'),
#  401: ("It's 'em.", "It's too late."),
#  402: ("It's 'em.", 'What?'),
#  403: ('Change your mind.', 'No.'),
#  404: ('Change your mind.', "I'm sorry."),
#  405: ("The heater's here.", 'Were you fooling with the power.'),
#  406: ("The heater's here.", "Oh yeah. What's that?"),
#  407: ('Ice cold water.', "That's my girl."),
#  408: ('Ice cold water.', 'Yeah.'),
#  409: ('What was that all about?', "I can't believe you said that."),
#  410: ('What was that all about?', "It wasn't a good time."),
#  411: ('Why?', "Because i'm so horny."),
#  412: ('Why?', "I don't know."),
#  413: ('Take a look at this.', "She's wearing a ring."),
#  414: ('Take a look at this.', "I'm not here."),
#  415: ('And started to run.', 'Good thinking.'),
#  416: ('And started to run.', 'Okay.'),
#  417: ('Oh yeah.', 'Dumbshit.'),
#  418: ('Oh yeah.', "I'm sorry. I'm sorry."),
#  419: ('Where to?', 'To see a man about a thing.'),
#  420: ('Where to?', 'Kennedy.'),
#  421: ('What about it?', 'For Schumann.'),
#  422: ('What about it?', "It's a lot pointed than you."),
#  423: ('Probably not.', 'How about the ones on that shelf?'),
#  424: ('Probably not.', "I'm not."),
#  425: ("Has any of 'em got an ax?",
#   'Political personal sexual anything at all against Mitchell.'),
#  426: ("Has any of 'em got an ax?", "I don't know."),
#  427: ("What's the frequency?",
#   "Computer what's the frequency of the transmission."),
#  428: ("What's the frequency?", 'Schizophrenic and marked.'),
#  429: ('God bless you sir.', 'Yeah okay.'),
#  430: ('God bless you sir.', "It's not a nice time."),
#  431: ('Get out.', 'The engine is still running.'),
#  432: ('Get out.', "You're going to get out of there."),
#  433: ('You just met me.', "Maybe i'm not understanding the question."),
#  434: ('You just met me.', "I don't know."),
#  435: ('Yeah.', 'Open your door.'),
#  436: ('Yeah.', "What's the matter?"),
#  437: ('Oh. Oh god. Gale.', 'What?'),
#  438: ('Oh. Oh god. Gale.', 'Okay.'),
#  439: ('Why would we?', 'Sweep the harbor.'),
#  440: ('Why would we?', 'Satisfy the curiosity.'),
#  441: ('You mind if I check things back here.', "It's fine."),
#  442: ('You mind if I check things back here.', 'Yes.'),
#  443: ("I'll take 'em all.", 'You must have quite some harem.'),
#  444: ("I'll take 'em all.", "No. You'll be fine."),
#  445: ("It's the only way it makes sense.", "I hope you're well."),
#  446: ("It's the only way it makes sense.", "I've been worried to you."),
#  447: ("That musta messed 'em up pretty bad.",
#   "What happened to 'em after that willie?"),
#  448: ("That musta messed 'em up pretty bad.", "I'm sorry."),
#  449: ('Tom. How are you? You look well.', "I'm well thank you."),
#  450: ('Tom. How are you? You look well.', "I'm fine."),
#  451: ('Go.', "''."),
#  452: ('Go.', "I can't."),
#  453: ('My daughter.', 'What about her?'),
#  454: ('My daughter.', 'What?'),
#  455: ('You driving this car.', 'Excuse me.'),
#  456: ('You driving this car.', "I don't know."),
#  457: ('Stop it stop it stop it.', "'sokay'sokay. I killed it."),
#  458: ('Stop it stop it stop it.', "I'm sorry."),
#  459: ('Paden sends his best.', 'I guess I put a good scare into him.'),
#  460: ('Paden sends his best.', 'What is that?'),
#  461: ("You're a liar.", "No it's the truth."),
#  462: ("You're a liar.", "I'm not."),
#  463: ('You should.', "You're right."),
#  464: ('You should.', "You're not going to."),
#  465: ('Serving with you has been an honor.',
#   'The honor was mine. Captain Riker.'),
#  466: ('Serving with you has been an honor.', "I don't think so."),
#  467: ('Sorry.', 'Wow.'),
#  468: ('Sorry.', "What do you think i'm doing?"),
#  469: ('Have you found a place to stay?', 'Yeah downtown.'),
#  470: ('Have you found a place to stay?', "I'll be fine."),
#  471: ('Well that depends. Do you have a bathroom?',
#   "Um yeah but it's for employees only."),
#  472: ('Well that depends. Do you have a bathroom?', 'Yeah.'),
#  473: ("You don't understand. It's her father.", 'Mr rose knows.'),
#  474: ("You don't understand. It's her father.", "It's not."),
#  475: ('Do you play the piano?', 'Come one will. I just want to know.'),
#  476: ('Do you play the piano?', 'A little.'),
#  477: ("I didn't realise.", 'Shut up freak. Monster. You are insignificant.'),
#  478: ("I didn't realise.", 'Is that all?'),
#  479: ('Throw your gun down now.',
#   'What are you talking about? What happened?'),
#  480: ('Throw your gun down now.', 'No.'),
#  481: ("He's floating. Take it home.", 'Hector.'),
#  482: ("He's floating. Take it home.", 'Why?'),
#  483: ('I will hear you but not now not here.', 'Who are you?'),
#  484: ('I will hear you but not now not here.', "You're sure."),
#  485: ("Do you know where you're headed?", "North. It's north."),
#  486: ("Do you know where you're headed?", 'No.'),
#  487: ("Where's Domini?", 'My room asleep last I checked.'),
#  488: ("Where's Domini?", "I don't know. I don't know."),
#  489: ('All right commander you wanna tell us anything.', 'Like what.'),
#  490: ('All right commander you wanna tell us anything.', 'We do.'),
#  491: ('Yeah.', 'Zoe come say hello to your father.'),
#  492: ('Yeah.', "What's your name?"),
#  493: ('Do you get high Sam?', "Only when i'm working."),
#  494: ('Do you get high Sam?', 'What do you mean?'),
#  495: ('Keep your mouth shut.', 'You tell me that in front of these creeps.'),
#  496: ('Keep your mouth shut.', "I'm not leaving without you."),
#  497: ('Terry slow down.', 'Okay.'),
#  498: ('Terry slow down.', 'What?'),
#  499: ('How are you doing?', 'Not too good.'),
#  500: ('How are you doing?', "I'm fine."),
#  501: ('But reverend mother everyone loves our new style.',
#   "It's brought people back to the church."),
#  502: ('But reverend mother everyone loves our new style.',
#   'Exactly. What do they think?'),
#  503: ('Oh for the love of god.', 'Shhhhhh.'),
#  504: ('Oh for the love of god.', 'Yeah.'),
#  505: ('Yeah.', 'Who?'),
#  506: ('Yeah.', "You're a writer."),
#  507: ('No. But once I heard.', 'What?'),
#  508: ('No. But once I heard.', 'The you re a.'),
#  509: ('You threatened miss Swann.', 'Only a little.'),
#  510: ('You threatened miss Swann.', "You're a man."),
#  511: ('Um yes.', "I've seen you. From the window."),
#  512: ('Um yes.', "I'm going to get a look."),
#  513: ('Maybe I will one of these days.', 'One of these days.'),
#  514: ('Maybe I will one of these days.', "Well you're not a little."),
#  515: ('What do you suggest?', 'That you come with me.'),
#  516: ('What do you suggest?', "I'm a man."),
#  517: ('He gives me a total boner.',
#   "He's like the biggest idiot of all time."),
#  518: ('He gives me a total boner.', "I'm sorry i'm not tired."),
#  519: ('Assuming your mysterious nun in right.',
#   "I've heard crazier things this week."),
#  520: ('Assuming your mysterious nun in right.', 'The slippers of the alien.'),
#  521: ('Kids.', 'Two.'),
#  522: ('Kids.', 'Oh god.'),
#  523: ('Excuse me.', "I said i'm not my sister."),
#  524: ('Excuse me.', "I'm not in the mood."),
#  525: ('Landon.', 'Later.'),
#  526: ('Landon.', 'No way.'),
#  527: ('Did you see that Wendy?', 'Yup.'),
#  528: ('Did you see that Wendy?', "I don't think so."),
#  529: ('Mister Mulvaney.', 'Yeah.'),
#  530: ('Mister Mulvaney.', "You're not a lawyer."),
#  531: ('I deal in divorce cases. Corporate investigations.',
#   "You've found missing persons before."),
#  532: ('I deal in divorce cases. Corporate investigations.',
#   "You're a man man."),
#  533: ('How is Nicole? Is she around?', "She's resting. In her room."),
#  534: ('How is Nicole? Is she around?', "He isn't in the same."),
#  535: ("It's gone to the top.", 'How high is that?'),
#  536: ("It's gone to the top.", "What's that?"),
#  537: ("I'm not going.", "You don't have a choice."),
#  538: ("I'm not going.", "I'm sorry you're not."),
#  539: ('You suck. You almost got us all killed.',
#   'You think this is so easy.'),
#  540: ('You suck. You almost got us all killed.', "I'm not hungry."),
#  541: ('I tell you once again surrender.', "It won't happen."),
#  542: ('I tell you once again surrender.', 'It was a lot of shit.'),
#  543: ('You are a moron.', "I'm afraid I have to insist you leave."),
#  544: ('You are a moron.', "What's that?"),
#  545: ("Can't break tradition? It's bad luck.", 'There is one more thing.'),
#  546: ("Can't break tradition? It's bad luck.", "I'm sorry."),
#  547: ('Hey you got nothing here.', 'I could have told you that.'),
#  548: ('Hey you got nothing here.', "I'm sure. I'm fine."),
#  549: ('So what.', 'The you re not that Jewish.'),
#  550: ('So what.', "I'm a bit."),
#  551: ("Don't like yours neither.", 'Kiss my ass.'),
#  552: ("Don't like yours neither.", "I'm not going to be here."),
#  553: ('Have you taken a wrong turn Mr Tyler?', 'You tell me.'),
#  554: ('Have you taken a wrong turn Mr Tyler?', "I'll have a look."),
#  555: ("I'm glad it's okay.", "It's okay. Regards to the family Sam."),
#  556: ("I'm glad it's okay.", "You're not a little."),
#  557: ('Do we now?', 'Quit bullshitting.'),
#  558: ('Do we now?', 'No.'),
#  559: ("You've been well.", 'Yes. You.'),
#  560: ("You've been well.", "Yeah. I don't know."),
#  561: ('Who?', 'Dyle or whatever his name is.'),
#  562: ('Who?', 'The guy.'),
#  563: ('Go die asshole.', 'Get a job.'),
#  564: ('Go die asshole.', "I'm going to be here."),
#  565: ('You have no personality.', 'Hey where does it say that.'),
#  566: ('You have no personality.', "I don't know."),
#  567: ('With food.', "No clothes. Stevie they changed into 'em."),
#  568: ('With food.', 'Yes.'),
#  569: ('No.', 'Why not?'),
#  570: ('No.', 'What do you want to do?'),
#  571: ("You're not a detective.", 'Neither are you magnum p I.'),
#  572: ("You're not a detective.", "I'm not going out."),
#  573: ('Gimme a dollar.', 'Fuck you.'),
#  574: ('Gimme a dollar.', "I'm sorry."),
#  575: ('Out for the evening.', "He's in Florida. Palm beach."),
#  576: ('Out for the evening.', "I'm sorry. I'm not hungry."),
#  577: ('Can you see well?', 'Yes very well thank you.'),
#  578: ('Can you see well?', "I don't."),
#  579: ('When was that?', 'About three.'),
#  580: ('When was that?', "When I wasn't in?"),
#  581: ('And a son by your ex wife. Joseph.',
#   'A son yeah. What about him? Joey.'),
#  582: ('And a son by your ex wife. Joseph.', "Who's the guy who?"),
#  583: ('Yes.', 'I love you. I love you.'),
#  584: ('Yes.', "You're not a thief."),
#  585: ('Thank you.', "That's perfectly all right."),
#  586: ('Thank you.', "You're welcome."),
#  587: ('Hmmm good coffee.', "You didn't answer my question."),
#  588: ('Hmmm good coffee.', "I'll take a little good."),
#  589: ('Down there.', 'And what did you do.'),
#  590: ('Down there.', 'What?'),
#  591: ('They look pretty smart I think.', "No they don't."),
#  592: ('They look pretty smart I think.', "You're kidding."),
#  593: ('I am this is it. B day.', "How's that Quince?"),
#  594: ('I am this is it. B day.', "I'm not sure."),
#  595: ('What stuff?', 'Morality.'),
#  596: ('What stuff?', 'The you re gonna be right in the way.'),
#  597: ('Yes.', 'Do you think the you re cannibals?'),
#  598: ('Yes.', "You're not a thief."),
#  599: ('Guys guys. I got it under control.', "Oh. He's got it under control."),
#  600: ('Guys guys. I got it under control.', "You're a man."),
#  601: ('So have you thought anymore about Dartmouth.', 'Yeah I have.'),
#  602: ('So have you thought anymore about Dartmouth.',
#   'Waddaya read a few minutes.'),
#  603: ('Chief mind if I take her.', 'Okay. But not water sports.'),
#  604: ('Chief mind if I take her.', "I'll get you a drink."),
#  605: ('What?', 'Mr Doyle.'),
#  606: ('What?', "I'm not sure. I'm sorry."),
#  607: ("Mace. You're a life saver.", 'Driving Mr Lenny.'),
#  608: ("Mace. You're a life saver.", 'I know.'),
#  609: ('Have you known her long?', 'I was married to her sister.'),
#  610: ('Have you known her long?', 'What?'),
#  611: ("That's me.", 'Not the u real u Chad Denby.'),
#  612: ("That's me.", "I'll take it."),
#  613: ('Sure. Twinkie.', "I'm chewing."),
#  614: ('Sure. Twinkie.', "What's wrong?"),
#  615: ('Then say so.', 'Yes Addison.'),
#  616: ('Then say so.', "I'll take you to you."),
#  617: ('Take her.', "What'd you say?"),
#  618: ('Take her.', 'What?'),
#  619: ('Probably looking for sparring partners.', 'I said that before.'),
#  620: ('Probably looking for sparring partners.', 'Yeah.'),
#  621: ("And then there's richard's burrito.", "What's that?"),
#  622: ("And then there's richard's burrito.", 'It was a very big idea.'),
#  623: ('He he wants me to help him skip town.', 'When? How?'),
#  624: ('He he wants me to help him skip town.', 'Will you.'),
#  625: ('About ten kilometers.', 'Sixty lira.'),
#  626: ('About ten kilometers.', "And it's a long time."),
#  627: ('I want him.', "He'll be dealt with."),
#  628: ('I want him.', "You're not a good man."),
#  629: ('It was at least as good as the sky.', 'Really. Okay.'),
#  630: ('It was at least as good as the sky.', "It's not going to be there."),
#  631: ('They fought against the Indians.', 'Same as they done in Mexico.'),
#  632: ('They fought against the Indians.', 'Yeah I did.'),
#  633: ("You're going to kill him. Kill Morpheus.",
#   "Trinity we don't have any other choice."),
#  634: ("You're going to kill him. Kill Morpheus.", 'What?'),
#  635: ('Not a chance.', "Yup you're looking at lucky thirteen."),
#  636: ('Not a chance.', 'What?'),
#  637: ('Your name is Conor.', 'Aye.'),
#  638: ('Your name is Conor.', 'Oscar. You poor.'),
#  639: ("It's a scene. Memorize it.", 'What?'),
#  640: ("It's a scene. Memorize it.", "Don't be a smart man."),
#  641: ('You you need to go to the police.', "I told you I can't not yet."),
#  642: ('You you need to go to the police.', "I'm not going."),
#  643: ('Jackie Shawn.', 'Yeah this is.'),
#  644: ('Jackie Shawn.', 'Yes.'),
#  645: ('Horses.', 'Horses.'),
#  646: ('Horses.', "You're not going to be here."),
#  647: ('Shhh. You know what I hear.', 'What?'),
#  648: ('Shhh. You know what I hear.', 'What?'),
#  649: ('Van Ripper turn the coach about.', 'What did you say?'),
#  650: ('Van Ripper turn the coach about.', "I'm not talking about a friend."),
#  651: ("Spock's tube.", 'David.'),
#  652: ("Spock's tube.", "You're a man."),
#  653: ('Cease fire. Look sharp.', 'Power levels quite low sir.'),
#  654: ('Cease fire. Look sharp.', 'Okay.'),
#  655: ('Shopping really. I should tell my friend.',
#   "Don't worry. He found the chocolate room."),
#  656: ('Shopping really. I should tell my friend.', 'No.'),
#  657: ('Have I seen you up in Balmoral mary?', 'I hope to go up next year.'),
#  658: ('Have I seen you up in Balmoral mary?', "That's a secret."),
#  659: ('Oh my god. You killed Kenny.', 'You bastard.'),
#  660: ('Oh my god. You killed Kenny.', 'It was a very good man.'),
#  661: ("I'll deal with her later.", "Good. Because i'm fed up."),
#  662: ("I'll deal with her later.", "You're not."),
#  663: ('How about inviting me over to dinner?', 'You know what I mean.'),
#  664: ('How about inviting me over to dinner?',
#   "Just a little i'm a professional."),
#  665: ("I'm going to kill him myself.", 'What about the money?'),
#  666: ("I'm going to kill him myself.", 'What?'),
#  667: ('An accident.', 'Shit. Oh shit.'),
#  668: ('An accident.', "I don't know."),
#  669: ('Mulholland drive.', 'Figures.'),
#  670: ('Mulholland drive.', 'Mulholland go.'),
#  671: ('What will you do?', 'I have to go back to Birmingham.'),
#  672: ('What will you do?', 'What do you want?'),
#  673: ('Use your other hand. Grab it.', "Help me. I don't want to die."),
#  674: ('Use your other hand. Grab it.', "Don't be ridiculous."),
#  675: ("The last one you'll ever see.", 'Perish the thought.'),
#  676: ("The last one you'll ever see.",
#   'Why do you think I was in the money?'),
#  677: ("They weren't human.", 'Come on. What were they jake?'),
#  678: ("They weren't human.", "I'm afraid you are."),
#  679: ('Your mother.', 'Allan Harris.'),
#  680: ('Your mother.', 'Yes.'),
#  681: ('Go to the movies.', 'All right.'),
#  682: ('Go to the movies.', 'Yeah.'),
#  683: ('Well.', "I'm thinking."),
#  684: ('Well.', 'Well what.'),
#  685: ('Are you the guy they called ray bones?', "Depends. Who's this?"),
#  686: ('Are you the guy they called ray bones?',
#   "I'm not a friend of my dad."),
#  687: ("And there's Dmitri.", "The honey trap. And there's the honey."),
#  688: ("And there's Dmitri.", 'Yes.'),
#  689: ("I don't understand.", "I made it up. It's horseshit."),
#  690: ("I don't understand.", "I don't know."),
#  691: ("Where's that lizard?", 'What lizard?'),
#  692: ("Where's that lizard?", 'Where is she?'),
#  693: ("Easy there partner I wasn't there.", 'I went over last night too.'),
#  694: ("Easy there partner I wasn't there.", 'What do you mean?'),
#  695: ('You get any sleep at all.', 'Some.'),
#  696: ('You get any sleep at all.', 'Not at all.'),
#  697: ("No. He's dead.", 'No way man.'),
#  698: ("No. He's dead.", "She's not supposed to."),
#  699: ("I wish you hadn't done that.", 'Why not?'),
#  700: ("I wish you hadn't done that.", "You don't."),
#  701: ('Pretty lame for such a smart kid.', 'Really professor I.'),
#  702: ('Pretty lame for such a smart kid.', "Your father doesn't."),
#  703: ('There shooting at something.', 'Doug.'),
#  704: ('There shooting at something.', 'What do you mean?'),
#  705: ('About what.', 'Whatever it is.'),
#  706: ('About what.', 'About the accident.'),
#  707: ('Please.', "I could scoop 'em out."),
#  708: ('Please.', "I'm sorry."),
#  709: ('And the children thought I should take a trip.', 'Yeah.'),
#  710: ('And the children thought I should take a trip.',
#   "And you'll be right in the river."),
#  711: ("Where's your gun your pistol?", 'In my bag in the car.'),
#  712: ("Where's your gun your pistol?", "I don't want to see."),
#  713: ('Do you walk home?', 'Uh huh.'),
#  714: ('Do you walk home?', "I don't know."),
#  715: ('I was upstairs.', 'I never saw you.'),
#  716: ('I was upstairs.', 'You have a good little.'),
#  717: ('To tell you the truth you did.',
#   'Do you have any more packages to deliver?'),
#  718: ('To tell you the truth you did.', 'Not completely.'),
#  719: ("That's right.", 'You sure got the hard part.'),
#  720: ("That's right.", 'What?'),
#  721: ('You know I never got your name.', 'Miss Itsu. In here please.'),
#  722: ('You know I never got your name.', 'You know that.'),
#  723: ('Gimme a report I want.', 'Ladies and gentlemen.'),
#  724: ('Gimme a report I want.', "We're not going anywhere."),
#  725: ('A loan officer.', "That's right a loan officer."),
#  726: ('A loan officer.', 'And you know the one.'),
#  727: ('My special friend.', 'Oh yeah.'),
#  728: ('My special friend.', 'And you said that.'),
#  729: ('You want death. Is it death you want?', 'Yes.'),
#  730: ('You want death. Is it death you want?', 'Yeah.'),
#  731: ('The sound of love.', 'Excuse me.'),
#  732: ('The sound of love.', 'The you re not going in there.'),
#  733: ("You're not trying to run away.",
#   'Just to be sure you can take my pack.'),
#  734: ("You're not trying to run away.", "What's wrong with me?"),
#  735: ('There was a review.', 'I think I remember.'),
#  736: ('There was a review.', 'What?'),
#  737: ('Listen this aingt for publication.', "I'm just resting my feet."),
#  738: ('Listen this aingt for publication.', "Maybe. We can't get it."),
#  739: ('Okay.', 'Mm hm.'),
#  740: ('Okay.', "What's going on?"),
#  741: ('College nickname.', 'You try martin.'),
#  742: ('College nickname.', 'Fro huh.'),
#  743: ("''.", 'Okay.'),
#  744: ("''.", "''."),
#  745: ("Swell only this man doesn't have a garden.", 'Oh. Neither do I voil.'),
#  746: ("Swell only this man doesn't have a garden.", 'Really mean.'),
#  747: ("There weren't any wires. I looked.",
#   "Mirrors then. It's done with mirrors."),
#  748: ("There weren't any wires. I looked.", "You're not a fool."),
#  749: ("Dignan those aren't running shoes.", 'Yes they are.'),
#  750: ("Dignan those aren't running shoes.", 'No.'),
#  751: ('Oh say Elaine gets down from Berkeley on Saturday.', 'Oh yes.'),
#  752: ('Oh say Elaine gets down from Berkeley on Saturday.', 'No shit.'),
#  753: ('I was worried.', "I'm sorry. How was your evening?"),
#  754: ('I was worried.', 'What?'),
#  755: ('Calm down calm down. Shh.', 'Shh. Hide her car in the back.'),
#  756: ('Calm down calm down. Shh.', 'What?'),
#  757: ('I see. Are you a socialist Mr Penfield?', 'Yes.'),
#  758: ('I see. Are you a socialist Mr Penfield?', "No no. I'm not a little."),
#  759: ('Then good night.', "So i'll get a fair shot."),
#  760: ('Then good night.', 'Good.'),
#  761: ("I'd fuck Elvis.", 'Really.'),
#  762: ("I'd fuck Elvis.", "I don't know."),
#  763: ("Look who's talking.", 'Yeah speak for yourself.'),
#  764: ("Look who's talking.", 'Leave him alone.'),
#  765: ('Then who was he.', 'Just some guy they found.'),
#  766: ('Then who was he.', "I don't know where he is."),
#  767: ("I don't know.", 'Is there anything I can do?'),
#  768: ("I don't know.", 'What do you mean?'),
#  769: ("You're hurt.", "I'll be fine."),
#  770: ("You're hurt.", "No. I'm going."),
#  771: ("Me fall. Let's get some drugs.", 'Drugs.'),
#  772: ("Me fall. Let's get some drugs.", 'Yes.'),
#  773: ("With a vengeance I hated 'em.", 'How come?'),
#  774: ("With a vengeance I hated 'em.", "I don't think so."),
#  775: ('Is this you?', "I don't know."),
#  776: ('Is this you?', 'What?'),
#  777: ('To the Cucamonga shopping center.', 'Oh yeah why you walking.'),
#  778: ('To the Cucamonga shopping center.', 'No.'),
#  779: ('And no one found the ring.', 'No sir we did not.'),
#  780: ('And no one found the ring.', "I don't know."),
#  781: ('Sorry. Thought I heard something.', 'Like what.'),
#  782: ('Sorry. Thought I heard something.', "You're a little."),
#  783: ("That name's familiar.", 'It is to me too.'),
#  784: ("That name's familiar.", 'Oh.'),
#  785: ('Want a ride?', "I'm all right."),
#  786: ('Want a ride?', 'No.'),
#  787: ("It's such a great song.", "It's a classic."),
#  788: ("It's such a great song.", 'So few.'),
#  789: ('Continued.', "Still you really don't believe it do you."),
#  790: ('Continued.', 'What do you think?'),
#  791: ("Where's the money?", "Get 'em in the vault."),
#  792: ("Where's the money?", 'What?'),
#  793: ('My life is not some deal. I.', "It's Boston Mr Mayflower."),
#  794: ('My life is not some deal. I.', 'What do you mean?'),
#  795: ('Yeah.', 'So did I.'),
#  796: ('Yeah.', "I'll get you a check."),
#  797: ('Not an easy day to forget.', 'No.'),
#  798: ('Not an easy day to forget.', "No i'm not with that."),
#  799: ("A scratch. Your arm's off.", "No it isn't."),
#  800: ("A scratch. Your arm's off.", "Let's get it out of here."),
#  801: ('We just smeared a skunk.', 'Shit.'),
#  802: ('We just smeared a skunk.', "I'm sorry."),
#  803: ('No. What a tragedy? What happened?', 'She changed.'),
#  804: ('No. What a tragedy? What happened?', "It's a all."),
#  805: ('Interesting.', 'Anything wrong.'),
#  806: ('Interesting.', 'What?'),
#  807: ("She's nervous naturally under the circumstances.",
#   'What circumstances?'),
#  808: ("She's nervous naturally under the circumstances.",
#   "Well what's that supposed to mean."),
#  809: ('But she ran away.', "That's right."),
#  810: ('But she ran away.', "I don't think so."),
#  811: ("We're going to finish that gin game.", 'Oh.'),
#  812: ("We're going to finish that gin game.", "I'll take the road."),
#  813: ('Want to buy a bed?', 'Not much.'),
#  814: ('Want to buy a bed?', 'Sure.'),
#  815: ("You're not coming Alex.", 'Yes I am.'),
#  816: ("You're not coming Alex.", "What's that supposed to mean?"),
#  817: ('Yes.', 'Are you a relative?'),
#  818: ('Yes.', "I'm sorry."),
#  819: ('Ready.', 'Yeah.'),
#  820: ('Ready.', 'Ready.'),
#  821: ('Okay give us the women.', 'Oh no women is all we got.'),
#  822: ('Okay give us the women.', 'Yes.'),
#  823: ('Are you married?', 'Divorced.'),
#  824: ('Are you married?', 'Yes.'),
#  825: ('Start a band.', "My father wouldn't approve of that that."),
#  826: ('Start a band.', "I'll be right there."),
#  827: ('Well yes your nose is. Very.', 'Is it?'),
#  828: ('Well yes your nose is. Very.', 'What?'),
#  829: ('You live a phony cheap cop out existence.', 'Yeah.'),
#  830: ('You live a phony cheap cop out existence.', 'Just like the other.'),
#  831: ('He told me my share was twenty five.', 'Mmm.'),
#  832: ('He told me my share was twenty five.', "I'm a little man."),
#  833: ('No.', 'Am I wrong?'),
#  834: ('No.', 'What?'),
#  835: ('Sara.', "Keep talking i'll find you."),
#  836: ('Sara.', ''),
#  837: ('You sod.', 'They came back.'),
#  838: ('You sod.', 'Yeah.'),
#  839: ('Uh how did this personality come about.', 'I was very charming.'),
#  840: ('Uh how did this personality come about.',
#   "It's not going to be a long."),
#  841: ('Just wondered what.', 'Why?'),
#  842: ('Just wondered what.', 'I saw a lot of effort up the time.'),
#  843: ("Of course not. He wouldn't be.", 'Who?'),
#  844: ("Of course not. He wouldn't be.", "You didn't think so."),
#  845: ('Jen listen.', 'I like really need a cigarette too.'),
#  846: ('Jen listen.', 'Can you do this for me?'),
#  847: ("Nothing that can't be exchanged.", 'Oh. Well. Good.'),
#  848: ("Nothing that can't be exchanged.", "You don't have to go to bed."),
#  849: ('Ever seen anything like that before.', 'No.'),
#  850: ('Ever seen anything like that before.', 'No.'),
#  851: ('Right.', "Aren't you."),
#  852: ('Right.', "You're welcome to the foot."),
#  853: ('No.', "Then don't sweat it George you know why."),
#  854: ('No.', "You're not making a move on your blood."),
#  855: ("I don't know.", 'Yes you do.'),
#  856: ("I don't know.", "You don't know."),
#  857: ('Yes.', 'Well have a good flight.'),
#  858: ('Yes.', "I'm going to settle."),
#  859: ('Now will you go.', 'No.'),
#  860: ('Now will you go.', "No I don't."),
#  861: ('Come on in.', 'I can explain about the portal darling.'),
#  862: ('Come on in.', 'What?'),
#  863: ('Travis.', 'Hey wizard.'),
#  864: ('Travis.', 'Yeah.'),
#  865: ('You name it.', 'Thousand dollars a game.'),
#  866: ('You name it.', 'No.'),
#  867: ("Didn't know you cared so much.", "I don't."),
#  868: ("Didn't know you cared so much.", "No I didn't."),
#  869: ("That wouldn't interest you.", "Where's Tyler?"),
#  870: ("That wouldn't interest you.", 'I know.'),
#  871: ('Wow. I have to give this some thought.', 'No time.'),
#  872: ('Wow. I have to give this some thought.', "What's your name?"),
#  873: ('Fine. Quite fine. And your royal highness.',
#   "Splendid. Now that I know you're around."),
#  874: ('Fine. Quite fine. And your royal highness.', "What's wrong?"),
#  875: ("Will you explain what's going on.", 'Patience lad.'),
#  876: ("Will you explain what's going on.", "I'm not sure."),
#  877: ("So what're you doing tonight.", 'Going out with Meurice.'),
#  878: ("So what're you doing tonight.", 'What do you think?'),
#  879: ('Like that.', 'Like that.'),
#  880: ('Like that.', 'Yes.'),
#  881: ('What do you do when you work?', 'I used to pitch.'),
#  882: ('What do you do when you work?', "I don't know."),
#  883: ('Please take it.', 'Well.'),
#  884: ('Please take it.', 'No.'),
#  885: ('Watch the store while I go home and change.',
#   'What happened to title dictates behavior?'),
#  886: ('Watch the store while I go home and change.',
#   "You can't be a little."),
#  887: ('But I have my clothes on.', 'Do it?'),
#  888: ('But I have my clothes on.', "I will. I'll get you a drink."),
#  889: ("What's the matter?", 'Nothing.'),
#  890: ("What's the matter?", "I don't know. I'm sorry."),
#  891: ("We got 'em.", "Take 'em. I want his head."),
#  892: ("We got 'em.", "I don't know what you're doing."),
#  893: ('I I.', 'Who are these from?'),
#  894: ('I I.', "You're a policeman."),
#  895: ('Give me your keys don.', "Please don't do this."),
#  896: ('Give me your keys don.', 'No.'),
#  897: ("I'm thinking about the duck breast.", 'Me too.'),
#  898: ("I'm thinking about the duck breast.", 'Who?'),
#  899: ('You need that real often.', 'Always hoping. Or this.'),
#  900: ('You need that real often.', "I'm not sure."),
#  901: ('Wow a lot of people showed up.', 'Yeah so what do we say.'),
#  902: ('Wow a lot of people showed up.', 'Put the gun down.'),
#  903: ('No sir no response.', 'Hmm. Very odd. Scotty. Progress report.'),
#  904: ('No sir no response.', 'No sir.'),
#  905: ("What's that?", 'The song. Are you sincere with me Fredo?'),
#  906: ("What's that?", 'The Germans are dropping.'),
#  907: ('Where does the chief get the drugs?',
#   'I dunno. Somewhere in south America I forget.'),
#  908: ('Where does the chief get the drugs?', 'The key.'),
#  909: ('Yeah Sid.', 'Right you got clicks anything.'),
#  910: ('Yeah Sid.', "I'm sorry."),
#  911: ('Well do you like him.', "I don't know."),
#  912: ('Well do you like him.', 'I did.'),
#  913: ('Wh you d she run away.', 'Oh you know. She was sixteen or seventeen.'),
#  914: ('Wh you d she run away.', "I didn't know."),
#  915: ("How's it sound?", 'The speech. Real good.'),
#  916: ("How's it sound?", "Well we're a good couple of bucks."),
#  917: ('Sure.', 'Well can I make an appointment.'),
#  918: ('Sure.', "You're not a man."),
#  919: ('What about crack? You a user.', 'I said I was a nun not an asshole.'),
#  920: ('What about crack? You a user.', "Well i'm not a good man."),
#  921: ('I am not.', 'Oh yes you are.'),
#  922: ('I am not.', "And you can't tell me what you do."),
#  923: ('What happened to me? What happened to you?', 'Yeah.'),
#  924: ('What happened to me? What happened to you?', 'I got a little risk.'),
#  925: ('The you ve tricked us.', "What's the crazy man saying lord?"),
#  926: ('The you ve tricked us.', "You're not going."),
#  927: ('What do you want nick?', 'Tell me about Catherine.'),
#  928: ('What do you want nick?', "I'm going to see you."),
#  929: ('It would be my child.', 'Sounds like you speaks from experience.'),
#  930: ('It would be my child.', "You're not a cop."),
#  931: ('From the store.', 'Fuck her.'),
#  932: ('From the store.', "Toward the end. What's the problem?"),
#  933: ("Well maybe that's it. I'm chicken.",
#   'Go on home. Just leave me the money.'),
#  934: ("Well maybe that's it. I'm chicken.", "I'm sorry."),
#  935: ("I think you'd make an excellent big brother.",
#   "That's what i'm thinking."),
#  936: ("I think you'd make an excellent big brother.",
#   "I'm a little too good."),
#  937: ('Do you believe this shit?', 'What happened?'),
#  938: ('Do you believe this shit?', 'What?'),
#  939: ("She's got a.", 'Does she have a pancreatic ulcer?'),
#  940: ("She's got a.", "And you're a cop."),
#  941: ('You and me tom.', 'What do you mean me?'),
#  942: ('You and me tom.', "Yeah. I'll be right back."),
#  943: ('How do you know all about this?', "I don't. Neither do you."),
#  944: ('How do you know all about this?', "I don't know. I don't know."),
#  945: ('I called you a taxi.', 'Very thoughtful.'),
#  946: ('I called you a taxi.', 'I love you.'),
#  947: ('Where are you?', "Jean i'm not."),
#  948: ('Where are you?', 'In the sub. Resetting the timer. Why?'),
#  949: ('Smells like a battle.', 'Are you a warrior?'),
#  950: ('Smells like a battle.', 'Mouse.'),
#  951: ("You're ready for the real thing.",
#   "At this point i'm ready for anything."),
#  952: ("You're ready for the real thing.", 'How do you know?'),
#  953: ('What?', "That's right."),
#  954: ('What?', 'The you re hauling misery into court.'),
#  955: ('No sir.', 'Thank you number one.'),
#  956: ('No sir.', "You're upset."),
#  957: ('Hi.', 'Hi. Are you busy?'),
#  958: ('Hi.', 'Oh. Hi.'),
#  959: ('Intelligent beyond our comprehension.', "Then it's god right."),
#  960: ('Intelligent beyond our comprehension.', 'A little a bit a little.'),
#  961: ('Where is it?', 'What?'),
#  962: ('Where is it?', 'The place of the street.'),
#  963: ("No it's not true you're lying.", 'Not this time Kat.'),
#  964: ("No it's not true you're lying.", "I'm not trying to."),
#  965: ('Wiping little circles with his bread.', 'Sucking away.'),
#  966: ('Wiping little circles with his bread.', "Well I don't think so."),
#  967: ("I'm fine.", 'You sure.'),
#  968: ("I'm fine.", "I don't know."),
#  969: ('We go someplace dangerous.', "Why didn't you say so?"),
#  970: ('We go someplace dangerous.', "We're going."),
#  971: ("Sollozzo knows mike's a civilian.", 'Ok but be careful.'),
#  972: ("Sollozzo knows mike's a civilian.",
#   "That's a good name. It's important."),
#  973: ("I don't know.", 'Is this bad for him?'),
#  974: ("I don't know.", 'What do you mean about?'),
#  975: ('Oh.', "Name your poison and i'll supply it."),
#  976: ('Oh.', 'What do we do?'),
#  977: ("It can't take that long.", 'Why?'),
#  978: ("It can't take that long.", "You're not a man man."),
#  979: ('You just said.', 'You need money to take a girl out.'),
#  980: ('You just said.', "I don't know."),
#  981: ('What are you talking about?', 'You know your plan.'),
#  982: ('What are you talking about?', "I'm a comedian."),
#  983: ('Light it man. Light it.', 'Not yet not yet.'),
#  984: ('Light it man. Light it.', "I'm sure."),
#  985: ("That's very generous.", 'The hell with it Eddie.'),
#  986: ("That's very generous.", "I'm not a doctor of the news."),
#  987: ('Now what.', 'Gotta sneeze.'),
#  988: ('Now what.', "We're going to go."),
#  989: ('What vou?', "I'm not the chemical weapons expert."),
#  990: ('What vou?', 'The wockers with the knockers.'),
#  991: ('You go out much.', 'After four years and now the question comes up.'),
#  992: ('You go out much.', "I'm not gonna be here."),
#  993: ("Don't get too cocky.", 'Why not?'),
#  994: ("Don't get too cocky.", "You're burned out."),
#  995: ('Keep fucking with me. Watch what happens.', 'All right then.'),
#  996: ('Keep fucking with me. Watch what happens.', 'The you re a open.'),
#  997: ("How's that?", 'She turned me out of the bed.'),
#  998: ("How's that?", 'A little better.'),
#  999: ('What are you doing here?', 'He wants to talk to you.'),
#  1000: ('What are you doing here?', 'I came to see you.')}

# %%
from collections import defaultdict
ans = defaultdict(lambda: [0, 0])

# %%
import csv

data = list()

with open('response.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        data += [row]

csvFile.close()

data = data[1:]

# %%
for row in data:
    if row[3] == 'bot':
        ans[int(row[2]) % 2][0] += 1
    else:
        ans[int(row[2]) % 2][1] += 1

# %%
ans
# Out:
# defaultdict(<function __main__.<lambda>()>, {1: [276, 291], 0: [289, 285]})

# %%
ans = defaultdict(lambda: [0, 0])

# %%
for row in data:
    if row[3] == 'bot':
        ans[int(row[2])][0] += 1
    else:
        ans[int(row[2])][1] += 1

# %%
for idx in range(1, 101):
    if idx <= 100:
        print(idx % 2 == 0 and 'bot' or 'human', res[idx], ans[idx])
# Out:
# human ('Would you excuse me for a moment?', 'Sure.') [4, 5]
# bot ('Would you excuse me for a moment?', "I'd like to know.") [2, 5]
# human ("It's so cruel.", 'No. He had the choice.') [3, 7]
# bot ("It's so cruel.", "And you're a good man.") [10, 0]
# human ('Thank you.', 'Want another one?') [9, 3]
# bot ('Thank you.', "I'll be in the back.") [1, 6]
# human ("Honey you'll wake the whole neighborhood.", 'Mom.') [10, 2]
# bot ("Honey you'll wake the whole neighborhood.", 'What is it?') [8, 1]
# human ('You said he was dead.', 'He is. But he was here.') [4, 3]
# bot ('You said he was dead.', "He's a girl.") [6, 10]
# human ('You gonna dig up that lad you s husband.', "I'll call the coroner.") [6, 6]
# bot ('You gonna dig up that lad you s husband.', "It's a nice time. I'm sorry.") [5, 4]
# human ('I better keep looking.', 'Where how?') [9, 5]
# bot ('I better keep looking.', "You're right.") [14, 2]
# human ('Jesus.', 'The business has changed.') [4, 2]
# bot ('Jesus.', "You're not going to do it.") [7, 4]
# human ('Hello.', 'Are you still coming?') [10, 4]
# bot ('Hello.', 'Hello.') [8, 0]
# human ("Try 'flintstone '.", 'What?') [3, 7]
# bot ("Try 'flintstone '.", "And what's the difference.") [6, 7]
# human ('Hey lost again.', 'But perhaps there is some some less radical solution.') [6, 4]
# bot ('Hey lost again.', "Don't touch.") [3, 5]
# human ('Do you smell shit?', 'Yeah.') [6, 9]
# bot ('Do you smell shit?', "No i'm not just sure.") [3, 7]
# human ("Of joanne's.", "Yeah. I'm her father.") [5, 6]
# bot ("Of joanne's.", "He's a little.") [9, 3]
# human ('How you guys doing?', "It's on.") [5, 1]
# bot ('How you guys doing?', 'Fine.') [1, 2]
# human ('Where you guys at?', 'Driving in circles waiting for.') [3, 4]
# bot ('Where you guys at?', "I'm not leaving.") [9, 4]
# human ('Have you succeeded in your task?', 'Any day now.') [10, 4]
# bot ('Have you succeeded in your task?', 'Not yet.') [0, 11]
# human ("How's the trout?", 'It tastes like fish.') [1, 8]
# bot ("How's the trout?", "I'm not sure.") [7, 3]
# human ('No.', 'Or your baby brother. What was his name?') [8, 3]
# bot ('No.', "You're not.") [9, 3]
# human ("Yeah it's me.", 'Judge hold on is your phone safe.') [9, 2]
# bot ("Yeah it's me.", 'What are you doing here?') [2, 4]
# human ("I don't get it.", "It doesn't make any sense.") [3, 10]
# bot ("I don't get it.", "I don't know.") [2, 3]
# human ('The Archdiocese called they want to settle her estate.', "And you're going to do that.") [9, 2]
# bot ('The Archdiocese called they want to settle her estate.', "And you're not making sense.") [1, 9]
# human ("I'm not sad.", "You're not.") [3, 3]
# bot ("I'm not sad.", "You're shouting at me.") [2, 8]
# human ("It's not right.", 'I hate it.') [2, 7]
# bot ("It's not right.", "You know what i'm saying.") [1, 8]
# human ('Tonight.', 'Any night.') [4, 5]
# bot ('Tonight.', "I'll be back in the morning.") [4, 7]
# human ('Now what.', "There's the fence.") [9, 3]
# bot ('Now what.', 'The beach.') [2, 6]
# human ('Right. Wait. A toast.', "You're just afraid to eat it.") [3, 5]
# bot ('Right. Wait. A toast.', 'A little a man.') [5, 2]
# human ("I'm going to see you again right.", "If it's okay with you.") [3, 9]
# bot ("I'm going to see you again right.", "I'm not going to hurt you.") [0, 10]
# human ('How was your flight?', 'Fine.') [3, 4]
# bot ('How was your flight?', 'Fine.') [7, 5]
# human ('Everything okay.', 'Yes thank you very much.') [1, 7]
# bot ('Everything okay.', 'Yeah.') [0, 6]
# human ('Affirmative.', 'The two surfer boys.') [8, 2]
# bot ('Affirmative.', "So you're not a guy.") [8, 1]
# human ('Good night dad.', 'Good night kiddo.') [0, 10]
# bot ('Good night dad.', 'Good night.') [1, 8]
# human ('Holding hands.', 'No not holding hands.') [1, 9]
# bot ('Holding hands.', "What's wrong?") [9, 4]
# human ("I'll take sixth. It's faster.", 'What?') [5, 5]
# bot ("I'll take sixth. It's faster.", "I'll be back in a few hours.") [4, 6]
# human ("Look he's in pretty good shape.", 'Poor Ike.') [8, 3]
# bot ("Look he's in pretty good shape.", "Hey don't be a nice man.") [7, 6]
# human ('You know I play tenor sax.', "But you're a girl thank goodness.") [5, 3]
# bot ('You know I play tenor sax.', 'Yes.') [11, 2]
# human ("I had you pegged didn't I.", 'You had the whole human race pegged.') [2, 11]
# bot ("I had you pegged didn't I.", 'Not really.') [10, 1]
# human ('Are you?', 'No.') [6, 2]
# bot ('Are you?', 'What do you think I do?') [5, 6]
# human ('Mmmm.', "It's a surprise you see.") [2, 6]
# bot ('Mmmm.', 'Right.') [4, 6]
# human ('You know what the Scottish call it.', 'No.') [2, 9]
# bot ('You know what the Scottish call it.', "I'm sorry. I'm not.") [3, 7]
# human ("It's a wonderful life.", 'Or the Bijou. Either one.') [9, 1]
# bot ("It's a wonderful life.", 'I know.') [13, 0]
# human ('Man that one made me puke.', 'You forgot something.') [8, 1]
# bot ('Man that one made me puke.', "Hey it's a little of a mystery.") [2, 7]
# human ('No.', 'Following the game at all.') [2, 4]
# bot ('No.', 'What do you want?') [3, 9]
# human ('I see.', 'Your foot. Give me your foot.') [4, 2]
# bot ('I see.', "You're a policeman.") [5, 7]
# human ('A symbol master.', 'What kind of symbol?') [3, 9]
# bot ('A symbol master.', 'In the world.') [6, 3]
# human ("Hey are you hungry. I'm hungry.", "Lois you're amazing.") [8, 1]
# bot ("Hey are you hungry. I'm hungry.", 'Sure.') [3, 10]
# human ('Did he try to?', 'No. Quid pro quo doctor.') [7, 2]
# bot ('Did he try to?', 'No.') [2, 11]
# human ("All right i'll try. See you later.", "Tomorrow at the gym. Don't forget.") [4, 9]
# bot ("All right i'll try. See you later.", 'Okay.') [1, 6]
# human ('I you know they should be insured.', 'What do you care?') [5, 4]
# bot ('I you know they should be insured.', "Don't be so literal.") [4, 7]
# human ('The readings suck.', "Maybe it's the tags that suck.") [1, 7]
# bot ('The readings suck.', 'Invasion.') [10, 1]
# human ('No. I meant.', 'What?') [2, 7]
# bot ('No. I meant.', "I've got a feeling.") [4, 5]
